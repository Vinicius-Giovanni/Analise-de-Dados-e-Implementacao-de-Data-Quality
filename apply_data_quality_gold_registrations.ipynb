# %%
# %sql

CREATE SCHEMA IF NOT EXISTS costumers_registrations.gold
COMMENT "Base de dados de clientes para consumo";

CREATE VOLUME IF NOT EXISTS costumers_registrations.gold.registrations
COMMENT "Volume de dados de clientes para consumo"

# %%
from pyspark.testing.utils import assertSchemaEqual

# %%
df = spark.read.parquet('/Volumes/costumers_registrations/raw/registrations')

# %%
df.write.format("delta").mode("append").saveAsTable("costumers_registrations.gold.registrations")
