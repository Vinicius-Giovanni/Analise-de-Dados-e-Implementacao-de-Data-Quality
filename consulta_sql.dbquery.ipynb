-- %%
SELECT r.id, o.id_pedido
FROM parquet.`/Volumes/costumers_registrations/raw/registrations`
AS r
JOIN parquet.`/Volumes/costumers_registrations/raw/orders`
AS o
ON r.id = o.id_pedido

SELECT *
FROM parquet.`/Volumes/costumers_registrations/raw/order`
LIMIT 100;

SELECT *
FROM parquet.`/Volumes/costumers_registrations/raw/orders`
LIMIT 100;
